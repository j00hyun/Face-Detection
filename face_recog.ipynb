# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#얼굴 인식 캐스케이드 파일 읽는다
face_cascade = cv2.CascadeClassifier('haarcascade_frontface.xml')

# %%
# 이미지 불러오기
image1 = cv2.imread('imglist/iu.jpg')
# 흑백이미지 만들기
grayImage1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
# 흑백이미지 그리기
plt.figure(figsize=(12,8))
plt.imshow(grayImage1, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
faces1 = face_cascade.detectMultiScale(grayImage1, 1.03, 5)
print(faces1.shape)
print("얼굴 개수: " + str(faces.shape[0]))
# Out:
# (1, 4)
# 얼굴 개수: 1

# %%
faces
# Out:
# array([[259, 158, 314, 314]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(grayImage,(x,y),(x+w,y+h),(255,0,0),2)
plt.figure(figsize=(12,12))
plt.imshow(grayImage, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
